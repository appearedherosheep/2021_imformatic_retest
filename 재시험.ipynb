# %%
x = {'a':1}
x.setdefault('key')
x
# Out:
# {'a': 1, 'key': None}

# %%
x.setdefault('key_2',3)
# 3 반환
x
# Out:
# {'a': 1, 'key': None, 'key_2': 3}

# %%
# 키가 문자열일 때만
x.update(key_2=20)
x
# Out:
# {'a': 1, 'key': None, 'key_2': 20}

# %%
x.update(key_3=40)
x
# Out:
# {'a': 1, 'key': None, 'key_2': 20, 'key_3': 40}

# %%
x.update(key_2=200,key_3=400)
x
# Out:
# {'a': 1, 'key': None, 'key_2': 200, 'key_3': 400}

# %%
# 키가 int형일 경우
x.update({1:'one'})
x
# Out:
# {'a': 1, 'key': None, 'key_2': 200, 'key_3': 400, 1: 'one'}

# %%
# 키-값 쌍 삭제 후 삭제한 값 반환
x.pop('key_2')
x
# Out:
# {'a': 1, 'key': None, 'key_3': 400, 1: 'one'}

# %%
x.pop('kkkkey',1111)
# Out:
# 1111

# %%
del x['key_3']
x
# Out:
# {'a': 1, 'key': None, 1: 'one'}

# %%
# 파이썬 3.6 이상 마지막 키-값 쌍을 삭제 후 튜플로 반환
x.popitem()
# Out:
# (1, 'one')

# %%
# 특정 키의 값 가져옴
x.get('a')
# Out:
# 1

# %%
x.get('kkkkkkey',1111)
# Out:
# 1111

# %%
print(x.items())
print(x.keys())
print(x.values())
# Out:
# dict_items([('a', 1), ('key', None)])
# dict_keys(['a', 'key'])
# dict_values([1, None])

# %%
list = ['a','b','c','d']
dic = dict.fromkeys(list)
print(dic)
dic_2 = dict.fromkeys(list,100)
print(dic_2)
# Out:
# {'a': None, 'b': None, 'c': None, 'd': None}
# {'a': 100, 'b': 100, 'c': 100, 'd': 100}

# %%
x.clear()
x
# Out:
# {}
